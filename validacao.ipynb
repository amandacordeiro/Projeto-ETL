# %%
import pandas as pd
import pandera as pa

# %%
df = pd.read_csv('ocorrencia.csv', sep=";", parse_dates=["ocorrencia_dia"], dayfirst=True)
df.head(10)
# Out:
#    codigo_ocorrencia ocorrencia_classificacao      ocorrencia_cidade  \
# 0              52242                INCIDENTE           PORTO ALEGRE
# 1              45331                 ACIDENTE              GUARULHOS
# 2              45333                 ACIDENTE                 VIAMÃO
# 3              45401                 ACIDENTE          SÃO SEBASTIÃO
# 4              45407                 ACIDENTE               SÃO SEPÉ
# 5              52243                INCIDENTE                UBATUBA
# 6              50713          INCIDENTE GRAVE               CAMPINAS
# 7              45334                INCIDENTE                  BELÉM
# 8              45391                 ACIDENTE  CONCEIÇÃO DAS ALAGOAS
# 9              52244                INCIDENTE             UBERLÂNDIA
#
#   ocorrencia_uf ocorrencia_pais ocorrencia_aerodromo ocorrencia_dia  \
# 0            RS          BRASIL                 SBPA     2012-01-05
# 1            SP          BRASIL                 SBGR     2012-01-06
# ...

# %%
schema = pa.DataFrameSchema(
    columns = { 
        "codigo_ocorrencia": pa.Column(pa.Int),
        "ocorrencia_classificacao": pa.Column(pa.Object),
        "ocorrencia_cidade": pa.Column(pa.Object),
        "ocorrencia_uf": pa.Column(pa.Object, pa.Check.str_length(2,2)),
        "ocorrencia_aerodromo": pa.Column(pa.Object),
        "ocorrencia_dia": pa.Column(pa.DateTime),
        "ocorrencia_hora": pa.Column(pa.String, pa.Check.str_matches(r'^([0-1]?[0-9]|[2][0-3]):([0-5][0-9])(:[0-5][0-9])?$'), nullable=True),
        "total_recomendacoes": pa.Column(pa.Int)
    }
)

# %%
schema.validate(df)
# Out:
# ---------------------------------------------------------------------------
# SchemaError                               Traceback (most recent call last)
# <ipython-input-10-dc85ea979a2b> in <module>
# ----> 1 schema.validate(df)
#
# ~\anaconda3\lib\site-packages\pandera\schemas.py in validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     511             return check_obj.pandera.add_schema(self)
#     512
# --> 513         return self._validate(
#     514             check_obj=check_obj,
#     515             head=head,
#
# ~\anaconda3\lib\site-packages\pandera\schemas.py in _validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     708                 check_results.append(check_utils.is_table(result))
#     709             except errors.SchemaError as err:
# --> 710                 error_handler.collect_error("schema_component_check", err)
#     711             except errors.SchemaErrors as err:
# ...

# %% [markdown]
# df.dtypes
# df.ocorrencia_dia.dt.month
