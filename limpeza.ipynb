# %%
import pandas as pd
import pandera as pa

# %%
df = pd.read_csv('ocorrencia.csv', sep=";", parse_dates=["ocorrencia_dia"], dayfirst=True)
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              52242               52242                INCIDENTE
# 1              45331               45331                 ACIDENTE
# 2              45333               45333                 ACIDENTE
# 3              45401               45401                 ACIDENTE
# 4              45407               45407                 ACIDENTE
#
#   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      PORTO ALEGRE            RS                 SBPA     2012-01-05
# 1         GUARULHOS            SP                 SBGR     2012-01-06
# 2            VIAMÃO            RS                  ***     2012-01-06
# 3     SÃO SEBASTIÃO            SP                  ***     2012-01-06
# 4          SÃO SEPÉ            RS                  ***     2012-01-06
#
#   ocorrencia_hora  total_recomendacoes
# 0        20:27:00                    0
# 1        13:44:00                    3
# ...

# %%
df.loc[:, 'ocorrencia_classificacao']
# Out:
# 0             INCIDENTE
# 1              ACIDENTE
# 2              ACIDENTE
# 3              ACIDENTE
# 4              ACIDENTE
#              ...
# 5162           ACIDENTE
# 5163           ACIDENTE
# 5164    INCIDENTE GRAVE
# 5165          INCIDENTE
# 5166          INCIDENTE
# Name: ocorrencia_classificacao, Length: 5167, dtype: object

# %%
df.loc[1:3]
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 1              45331               45331                 ACIDENTE
# 2              45333               45333                 ACIDENTE
# 3              45401               45401                 ACIDENTE
#
#   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 1         GUARULHOS            SP                 SBGR     2012-01-06
# 2            VIAMÃO            RS                  ***     2012-01-06
# 3     SÃO SEBASTIÃO            SP                  ***     2012-01-06
#
#   ocorrencia_hora  total_recomendacoes
# 1        13:44:00                    3
# 2        13:00:00                    0
# 3        17:00:00                    0

# %%
df.codigo_ocorrencia.is_unique
# Out:
# True

# %%
#declarando indice
df.set_index('codigo_ocorrencia', inplace=True)

# %%
df.head()
# Out:
#                    codigo_ocorrencia2 ocorrencia_classificacao  \
# codigo_ocorrencia
# 52242                           52242                INCIDENTE
# 45331                           45331                 ACIDENTE
# 45333                           45333                 ACIDENTE
# 45401                           45401                 ACIDENTE
# 45407                           45407                 ACIDENTE
#
#                   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# codigo_ocorrencia
# 52242                  PORTO ALEGRE            RS                 SBPA
# 45331                     GUARULHOS            SP                 SBGR
# 45333                        VIAMÃO            RS                  ***
# 45401                 SÃO SEBASTIÃO            SP                  ***
# 45407                      SÃO SEPÉ            RS                  ***
#
#                   ocorrencia_dia ocorrencia_hora  total_recomendacoes
# codigo_ocorrencia
# ...

# %%
df.loc[45331]
# Out:
# codigo_ocorrencia2                        45331
# ocorrencia_classificacao               ACIDENTE
# ocorrencia_cidade                     GUARULHOS
# ocorrencia_uf                                SP
# ocorrencia_aerodromo                       SBGR
# ocorrencia_dia              2012-01-06 00:00:00
# ocorrencia_hora                        13:44:00
# total_recomendacoes                           3
# Name: 45331, dtype: object

# %%
#remover indice e voltar ao original
df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0               52242                INCIDENTE      PORTO ALEGRE
# 1               45331                 ACIDENTE         GUARULHOS
# 2               45333                 ACIDENTE            VIAMÃO
# 3               45401                 ACIDENTE     SÃO SEBASTIÃO
# 4               45407                 ACIDENTE          SÃO SEPÉ
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0            RS                 SBPA     2012-01-05        20:27:00
# 1            SP                 SBGR     2012-01-06        13:44:00
# 2            RS                  ***     2012-01-06        13:00:00
# 3            SP                  ***     2012-01-06        17:00:00
# 4            RS                  ***     2012-01-06        16:30:00
#
#    total_recomendacoes
# 0                    0
# 1                    3
# 2                    0
# 3                    0
# 4                    0

# %%
#alterando dados
df.loc[, 'ocorrencia_aerodromo'] = ''

# %%
df.head(3)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              52242               52242                INCIDENTE
# 1              45331               45331                 ACIDENTE
# 2              45333               45333                 ACIDENTE
#
#   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      PORTO ALEGRE            RS                          2012-01-05
# 1         GUARULHOS            SP                 SBGR     2012-01-06
# 2            VIAMÃO            RS                  ***     2012-01-06
#
#   ocorrencia_hora  total_recomendacoes
# 0        20:27:00                    0
# 1        13:44:00                    3
# 2        13:00:00                    0

# %%
df.loc[1] = 20

# %%
df.head(2)
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0               52242                INCIDENTE      PORTO ALEGRE
# 1                  20                       20                20
#
#   ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# 0            RS                       2012-01-05 00:00:00        20:27:00
# 1            20                   20                   20              20
#
#    total_recomendacoes
# 0                    0
# 1                   20

# %%
df.loc[:,'total_recomendacoes'] = 5

# %%
df.head(5)
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0               52242                INCIDENTE      PORTO ALEGRE
# 1                  20                       20                20
# 2               45333                 ACIDENTE            VIAMÃO
# 3               45401                 ACIDENTE     SÃO SEBASTIÃO
# 4               45407                 ACIDENTE          SÃO SEPÉ
#
#   ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# 0            RS                       2012-01-05 00:00:00        20:27:00
# 1            20                   20                   20              20
# 2            RS                  ***  2012-01-06 00:00:00        13:00:00
# 3            SP                  ***  2012-01-06 00:00:00        17:00:00
# 4            RS                  ***  2012-01-06 00:00:00        16:30:00
#
#    total_recomendacoes
# 0                    5
# 1                    5
# 2                    5
# 3                    5
# ...

# %%
#fazendo backup da coluna
df['ocorrencia_uf_bkp'] = df.ocorrencia_uf

# %%
df.head(20)
# Out:
#     codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0               52242               52242                INCIDENTE
# 1               45331               45331                    GRAVE
# 2               45333               45333                 ACIDENTE
# 3               45401               45401                    GRAVE
# 4               45407               45407                 ACIDENTE
# 5               52243               52243                    GRAVE
# 6               50713               50713                    GRAVE
# 7               45334               45334                INCIDENTE
# 8               45391               45391                 ACIDENTE
# 9               52244               52244                INCIDENTE
# 10              45332               45332                 ACIDENTE
# 11              52245               52245                INCIDENTE
# 12              45396               45396          INCIDENTE GRAVE
# ...

# %%
df.loc[:, 'ocorrencia_uf'] = df.ocorrencia_uf_bkp

# %%
df.loc[df.ocorrencia_uf == 'SP', ['ocorrencia_classificacao']] = 'GRAVE'

# %%
df['ocorrencia_classificacaoBKP'] = df.ocorrencia_classificacao

# %%
df.loc[df.ocorrencia_uf == 'SP']
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 1                 45331               45331                    GRAVE
# 3                 45401               45401                    GRAVE
# 5                 52243               52243                    GRAVE
# 6                 50713               50713                    GRAVE
# 13                45408               45408                    GRAVE
# ...                 ...                 ...                      ...
# 5148              80441               80441                    GRAVE
# 5157              80453               80453                    GRAVE
# 5158              80454               80454                    GRAVE
# 5161              80456               80456                    GRAVE
# 5163              80452               80452                    GRAVE
#
#       ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 52242               52242                INCIDENTE
# 1                 45331               45331                 ACIDENTE
# 2                 45333               45333                 ACIDENTE
# 3                 45401               45401                 ACIDENTE
# 4                 45407               45407                 ACIDENTE
# ...                 ...                 ...                      ...
# 5162              80458               80458                 ACIDENTE
# 5163              80452               80452                 ACIDENTE
# 5164              80457               80457          INCIDENTE GRAVE
# 5165              80460               80460                INCIDENTE
# 5166              80467               80467                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %% [raw]
# ocorrencia_uf
# **
# ocorrencia_aerodromo
# ###!
# ####
# **
# ***
# ****
# ocorrencia_hora
# NULL

# %%
#substituindo valores
df.loc[df.ocorrencia_uf == '****', ['ocorrencia_uf']] = pd.NA

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              52242               52242                INCIDENTE
# 1              45331               45331                 ACIDENTE
# 2              45333               45333                 ACIDENTE
# 3              45401               45401                 ACIDENTE
# 4              45407               45407                 ACIDENTE
#
#   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      PORTO ALEGRE            RS                 SBPA     2012-01-05
# 1         GUARULHOS            SP                 SBGR     2012-01-06
# 2            VIAMÃO            RS                    0     2012-01-06
# 3     SÃO SEBASTIÃO            SP                    0     2012-01-06
# 4          SÃO SEPÉ            RS                    0     2012-01-06
#
#   ocorrencia_hora  total_recomendacoes
# 0        20:27:00                    0
# 1        13:44:00                    3
# ...

# %%
#usando o replace para alterar várias linhas
df.replace(['**','###!','####','***','****','NULL'], pd.NA, inplace=True)

# %%
#para saber quantos dados não informados o dataframe possui
df.isna().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  2
# ocorrencia_aerodromo        1905
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %%
#colocando valor nos dados nao informados
df.fillna(10, inplace=True)

# %%
#alterando alguns dados nao informados
df.replace([10], pd.NA, inplace=True)

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              52242               52242                INCIDENTE
# 1              45331               45331                 ACIDENTE
# 2              45333               45333                 ACIDENTE
# 3              45401               45401                 ACIDENTE
# 4              45407               45407                 ACIDENTE
#
#   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      PORTO ALEGRE            RS                 SBPA     2012-01-05
# 1         GUARULHOS            SP                 SBGR     2012-01-06
# 2            VIAMÃO            RS                 <NA>     2012-01-06
# 3     SÃO SEBASTIÃO            SP                 <NA>     2012-01-06
# 4          SÃO SEPÉ            RS                 <NA>     2012-01-06
#
#   ocorrencia_hora  total_recomendacoes ocorrencia_uf_bkp
# 0        20:27:00                    0                RS
# ...

# %%
#alterando somente alguns dados NA
df.fillna(value={'ocorrencia_uf':10}, inplace=True)

# %%
df.isna().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  0
# ocorrencia_aerodromo        1904
# ocorrencia_dia                 0
# ocorrencia_hora                0
# total_recomendacoes            0
# ocorrencia_uf_bkp              0
# dtype: int64

# %%
#excluindo coluna
df.drop(['ocorrencia_classificacaoBKP'], axis=1, inplace=True)

# %%
#excluir todos os valores nao informados
df.dropna()
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 52242               52242                INCIDENTE
# 1                 45331               45331                 ACIDENTE
# 6                 50713               50713          INCIDENTE GRAVE
# 7                 45334               45334                INCIDENTE
# 9                 52244               52244                INCIDENTE
# ...                 ...                 ...                      ...
# 5160              80451               80451                INCIDENTE
# 5161              80456               80456                INCIDENTE
# 5164              80457               80457          INCIDENTE GRAVE
# 5165              80460               80460                INCIDENTE
# 5166              80467               80467                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
#excluindo o NA por coluna
df.dropna(subset=['ocorrencia_hora'], inplace=True)

# %%
#excluindo valores duplicados
df.drop_duplicates(inplace=True)
